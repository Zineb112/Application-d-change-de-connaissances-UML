-- %% [markdown]
-- # [Kapp]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [Kapp]    Script Date: 08/01/2021 09:51:55 ******/
CREATE DATABASE [Kapp]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'Kapp', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL15.MSSQLSERVER\MSSQL\DATA\Kapp.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'Kapp_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL15.MSSQLSERVER\MSSQL\DATA\Kapp_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT
GO
ALTER DATABASE [Kapp] SET COMPATIBILITY_LEVEL = 150
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [Kapp].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [Kapp] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [Kapp] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [Kapp] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [Kapp] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [Kapp] SET ARITHABORT OFF 
GO
ALTER DATABASE [Kapp] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [Kapp] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [Kapp] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [Kapp] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [Kapp] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [Kapp] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [Kapp] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [Kapp] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [Kapp] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [Kapp] SET  DISABLE_BROKER 
GO
ALTER DATABASE [Kapp] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [Kapp] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [Kapp] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [Kapp] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [Kapp] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [Kapp] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [Kapp] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [Kapp] SET RECOVERY FULL 
GO
ALTER DATABASE [Kapp] SET  MULTI_USER 
GO
ALTER DATABASE [Kapp] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [Kapp] SET DB_CHAINING OFF 
GO
ALTER DATABASE [Kapp] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [Kapp] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [Kapp] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [Kapp] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
EXEC sys.sp_db_vardecimal_storage_format N'Kapp', N'ON'
GO
ALTER DATABASE [Kapp] SET QUERY_STORE = OFF
GO

-- %% [markdown]
-- # [dbo].[Admin]

-- %%
USE [Kapp]
GO

-- %%
/****** Object:  Table [dbo].[Admin]    Script Date: 08/01/2021 09:51:56 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Admin](
	[id] [int] NOT NULL,
	[user id] [int] NOT NULL,
 CONSTRAINT [PK_Admin] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Question]

-- %%
/****** Object:  Table [dbo].[Question]    Script Date: 08/01/2021 09:51:56 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Question](
	[id] [int] NOT NULL,
	[user id] [int] NOT NULL,
 CONSTRAINT [PK_Question] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Questionneur]

-- %%
/****** Object:  Table [dbo].[Questionneur]    Script Date: 08/01/2021 09:51:56 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Questionneur](
	[id] [int] NOT NULL,
	[user id] [int] NULL,
 CONSTRAINT [PK_Questionneur] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Répondant]

-- %%
/****** Object:  Table [dbo].[Répondant]    Script Date: 08/01/2021 09:51:56 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Répondant](
	[id] [int] NOT NULL,
	[user id] [int] NOT NULL,
	[Tag id] [nchar](10) NOT NULL,
 CONSTRAINT [PK_Répondant] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Réponse]

-- %%
/****** Object:  Table [dbo].[Réponse]    Script Date: 08/01/2021 09:51:56 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Réponse](
	[id] [int] NOT NULL,
	[user id] [int] NOT NULL,
 CONSTRAINT [PK_Réponse] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Tag]

-- %%
/****** Object:  Table [dbo].[Tag]    Script Date: 08/01/2021 09:51:56 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Tag](
	[id] [int] NOT NULL,
	[user id] [int] NULL,
 CONSTRAINT [PK_Tag] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Utilisateur]

-- %%
/****** Object:  Table [dbo].[Utilisateur]    Script Date: 08/01/2021 09:51:56 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Utilisateur](
	[Nom] [nchar](10) NOT NULL,
	[prénom] [nchar](10) NOT NULL,
	[Email] [nchar](10) NOT NULL,
	[id] [int] NOT NULL,
 CONSTRAINT [PK_Utilisateur] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [Kapp]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [Kapp] SET  READ_WRITE 
GO
